# %%
from anthropic import Anthropic

# %%
# Load environment variables
from helper import load_env
load_env()

MODEL_NAME="claude-3-5-sonnet-20241022"
client = Anthropic()

# %%
# example to web search tool.
import anthropic

client = anthropic.Anthropic()

response = client.messages.create(
    model=MODEL_NAME,
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": "Give me the list of Models from Anthropic release in the year 2025"
        }
    ],
    tools=[{
        "type": "web_search_20250305",
        "name": "web_search",
        "max_uses": 4
    }]
)
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "msg_01G62CwPre3NnFc3QctKDz3r",
#   "content": [
#     {
#       "text": "Let me search for information about Anthropic's model releases in 2025.",
#       "type": "text"
#     },
#     {
#       "text": null,
#       "type": "server_tool_use",
#       "id": "srvtoolu_01Q8vHvGSfhM1GeuoKwpnEmi",
#       "name": "web_search",
#       "input": {
#         "query": "Anthropic AI models released 2025 Claude"
#       }
#     },
#     {
#       "text": null,
#       "type": "web_search_tool_result",
#       "tool_use_id": "srvtoolu_01Q8vHvGSfhM1GeuoKwpnEmi",
#       "content": [
#         {
#           "type": "web_search_result",
#           "title": "Claude Opus 4.1 \\ Anthropic",
#           "url": "https://www.anthropic.com/news/claude-opus-4-1",
#           "encrypted_content": "...",
#           "page_age": null
#         },
#         {
#           "type": "web_search_result",
#           "title": "Introducing Claude 4 \\ Anthropic",
# ...

# %%
import anthropic

client = anthropic.Anthropic()

response = client.beta.messages.create(
    model="claude-3-5-sonnet-20241022",
    max_tokens=1024,
    tools=[
        {
            "type": "text_editor_20241022",
            "name": "str_replace_editor"
        }
    ],
    messages=[
        {
            "role": "user", 
            "content": "There's a syntax error in my primes.py file. Can you help me fix it?"
        }
    ],
    betas=["computer-use-2024-10-22"]  # Required for Claude 3.5
)

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "msg_01FoN5QKUdtJqKMSxnnoURg8",
#   "content": [
#     {
#       "text": "I'll help you examine and fix the syntax error in your primes.py file. First, let me look at its contents.",
#       "type": "text"
#     },
#     {
#       "id": "toolu_013wpGrHziP9qCQWz9At9HEw",
#       "input": {
#         "command": "view",
#         "path": "/repo/primes.py"
#       },
#       "name": "str_replace_editor",
#       "type": "tool_use"
#     }
#   ],
#   "model": "claude-3-5-sonnet-20241022",
#   "role": "assistant",
#   "stop_reason": "tool_use",
#   "stop_sequence": null,
#   "type": "message",
#   "usage": {
#     "cache_creation_input_tokens": 0,
#     "cache_read_input_tokens": 0,
#     "input_tokens": 1195,
#     "output_tokens": 106,
#     "cache_creation": {
#       "ephemeral_5m_input_tokens": 0,
#       "ephemeral_1h_input_tokens": 0
#     },
#     "service_tier": "standard"
#   }
# }

# %%
import anthropic

client = anthropic.Anthropic()

response = client.beta.messages.create(
    model="claude-3-5-sonnet-20241022",
    max_tokens=1024,
    tools=[
        {
            "type": "bash_20250124",
            "name": "bash"
        }
    ],
    messages=[
        {"role": "user", "content": "List all Python files in the current directory. and the current path."}
    ],
    betas=["computer-use-2024-10-22"]  # Required for Claude 3.5
)

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "msg_01AtT4YpWqtDj17BDBG6YqZ1",
#   "content": [
#     {
#       "text": "I'll help you list Python files in the current directory and show the current path. I'll use the `bash` command for this:",
#       "type": "text"
#     },
#     {
#       "id": "toolu_019gRahBpPYjgiXgy3ZwtA8Y",
#       "input": {
#         "command": "pwd && echo -e \"\\nPython files in current directory:\" && ls *.py"
#       },
#       "name": "bash",
#       "type": "tool_use"
#     }
#   ],
#   "model": "claude-3-5-sonnet-20241022",
#   "role": "assistant",
#   "stop_reason": "tool_use",
#   "stop_sequence": null,
#   "type": "message",
#   "usage": {
#     "cache_creation_input_tokens": 0,
#     "cache_read_input_tokens": 0,
#     "input_tokens": 578,
#     "output_tokens": 98,
#     "cache_creation": {
#       "ephemeral_5m_input_tokens": 0,
#       "ephemeral_1h_input_tokens": 0
#     },
#     "service_tier": "standard"
#   }
# }
